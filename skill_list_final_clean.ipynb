# %%
import pandas as pd
import sqlalchemy 
import sql_functions as sf

# %%
# load jobs & skill data

schema = 'capstone_datacvpro'

skills = sf.get_dataframe(f' SELECT * FROM {schema}.skills_count_total')

# %% [markdown]
# - delete:
#     - Data Analysis(3), Business Intelligence(18)
#
# - limitations:
#     - writing can include actual writing skills or eg. writing code

# %%
skills.head(20)
# Out:
#                                        skill            skill_clean  \
# 0                 SQL (Programming Language)                    sql
# 1                             Communications          communication
# 2                              Data Analysis          data analysis
# 3              Python (Programming Language)                 python
# 4                           Computer Science       computer science
# 5   Tableau (Business Intelligence Software)                tableau
# 6                                 Statistics             statistics
# 7                                   Research               research
# 8                                  Dashboard              dashboard
# 9                              Visualization          visualization
# 10                                   Writing                writing
# 11                               Programming            programming
# 12                             Presentations           presentation
# 13                              Data Quality           data quality
# 14                            SAS (Software)                    sas
# 15                                   Finance                finance
# 16                           Data Management        data management
# 17                                Leadership             leadership
# 18                     Business Intelligence  business intelligence
# 19                         Analytical Skills      analytical skills
#
#           type  count_20  frequency_%_20  count_current  frequency_%_current
# 0   Hard Skill      1389           61.65          18351                57.31
# 1   Soft Skill      1154           51.22          16024                50.04
# 2   Hard Skill       717           31.82          13207                41.24
# 3   Hard Skill       637           28.27           9553                29.83
# 4   Hard Skill       622           27.61           8160                25.48
# 5   Hard Skill       620           27.52          10113                31.58
# 6   Hard Skill       563           24.99           8234                25.71
# 7   Soft Skill       559           24.81           9400                29.35
# 8   Hard Skill       533           23.66           9736                30.40
# 9   Hard Skill       517           22.95          11400                35.60
# 10  Soft Skill       452           20.06           4782                14.93
# 11  Hard Skill       439           19.49           4996                15.60
# 12  Soft Skill       439           19.49           7852                24.52
# 13  Hard Skill       411           18.24           5283                16.50
# 14  Hard Skill       411           18.24           4991                15.59
# 15  Hard Skill       403           17.89           6532                20.40
# 16  Hard Skill       400           17.75           5019                15.67
# 17  Soft Skill       388           17.22           7871                24.58
# 18  Hard Skill       342           15.18           5950                18.58
# 19  Soft Skill       327           14.51           3700                11.55

# %%
# drop Data Analysis, Business Intelligence

skills.drop([2,18], inplace=True)
skills = skills.reset_index(drop=True)

# %%
# sort by frequency current & limit to Top 20

skills = skills.sort_values('frequency_%_current', ascending=False).head(50).reset_index(drop=True)

# %%
skills
# Out:
#                                        skill                  skill_clean  \
# 0                 SQL (Programming Language)                          sql
# 1                             Communications                communication
# 2                              Visualization                visualization
# 3   Tableau (Business Intelligence Software)                      tableau
# 4                                  Dashboard                    dashboard
# 5              Python (Programming Language)                       python
# 6                                   Research                     research
# 7                                 Statistics                   statistics
# 8                           Computer Science             computer science
# 9                                 Leadership                   leadership
# 10                             Presentations                 presentation
# 11                                  Power BI                     power bi
# 12                                   Finance                      finance
# 13                                  Planning                     planning
# 14                              Data Science                 data science
# 15                              Data Quality                 data quality
# 16                           Data Management              data management
# 17                               Programming                  programming
# 18                            SAS (Software)                          sas
# 19                                 Economics                    economics
# 20                                   Writing                      writing
# 21                                     Sales                        sales
# 22              Git (Version Control System)                          git
# 23                                Innovation                   innovation
# 24                             Collaboration                collaboration
# 25                               Integration                  integration
# 26                         Analytical Skills            analytical skills
# 27                                Automation                   automation
# 28                          Business Process             business process
# 29                        Project Management           project management
# 30                   Perspective (Graphical)                  perspective
# 31                               Scale (Map)                        scale
# 32                 Transformation (Genetics)               transformation
# 33                               Data Mining                  data mining
# 34                             Data Modeling                data modeling
# 35                           Data Collection              data collection
# 36      Tracking (Commercial Airline Flight)                     tracking
# 37                                Consulting                   consulting
# 38                          Microsoft Office             microsoft office
# 39                    Information Technology       information technology
# 40                           Decision Making              decision making
# 41                           Problem Solving              problem solving
# 42                       Information Systems          information systems
# 43                           Data Governance              data governance
# 44                           Microsoft Excel              microsoft excel
# 45                  R (Programming Language)                            R
# 46                          Machine Learning             machine learning
# 47                               Supervision                  supervision
# 48               Business Intelligence Tools  business intelligence tools
# 49                                Accounting                   accounting
#
#           type  count_20  frequency_%_20  count_current  frequency_%_current
# 0   Hard Skill      1389           61.65          18351                57.31
# 1   Soft Skill      1154           51.22          16024                50.04
# 2   Hard Skill       517           22.95          11400                35.60
# 3   Hard Skill       620           27.52          10113                31.58
# 4   Hard Skill       533           23.66           9736                30.40
# 5   Hard Skill       637           28.27           9553                29.83
# 6   Soft Skill       559           24.81           9400                29.35
# 7   Hard Skill       563           24.99           8234                25.71
# 8   Hard Skill       622           27.61           8160                25.48
# 9   Soft Skill       388           17.22           7871                24.58
# 10  Soft Skill       439           19.49           7852                24.52
# 11  Hard Skill       180            7.99           6616                20.66
# 12  Hard Skill       403           17.89           6532                20.40
# 13  Soft Skill       287           12.74           6107                19.07
# 14  Hard Skill       251           11.14           5423                16.94
# 15  Hard Skill       411           18.24           5283                16.50
# 16  Hard Skill       400           17.75           5019                15.67
# 17  Hard Skill       439           19.49           4996                15.60
# 18  Hard Skill       411           18.24           4991                15.59
# 19  Hard Skill       203            9.01           4851                15.15
# 20  Soft Skill       452           20.06           4782                14.93
# 21  Soft Skill       272           12.07           4709                14.71
# 22  Hard Skill       298           13.23           4695                14.66
# 23  Soft Skill       201            8.92           4612                14.40
# 24  Soft Skill       245           10.87           4542                14.18
# 25  Soft Skill       253           11.23           4253                13.28
# 26  Soft Skill       327           14.51           3700                11.55
# 27  Hard Skill       214            9.50           3511                10.96
# 28  Hard Skill       213            9.45           3415                10.66
# 29  Hard Skill       300           13.32           3350                10.46
# 30  Hard Skill       132            5.86           3310                10.34
# 31  Hard Skill       179            7.94           3281                10.25
# 32  Hard Skill       196            8.70           3236                10.11
# 33  Hard Skill       257           11.41           3188                 9.96
# 34  Hard Skill       168            7.46           3027                 9.45
# 35  Hard Skill       282           12.52           3011                 9.40
# 36  Hard Skill       205            9.10           3004                 9.38
# 37  Soft Skill       227           10.08           2998                 9.36
# 38  Soft Skill       205            9.10           2918                 9.11
# 39  Soft Skill       190            8.43           2866                 8.95
# 40  Soft Skill       155            6.88           2747                 8.58
# 41  Soft Skill       232           10.30           2690                 8.40
# 42  Hard Skill       227           10.08           2688                 8.39
# 43  Hard Skill       172            7.63           2498                 7.80
# 44  Soft Skill       139            6.17           2300                 7.18
# 45  Hard Skill       158            7.01           2245                 7.01
# 46  Hard Skill       180            7.99           2192                 6.85
# 47  Soft Skill       159            7.06           2194                 6.85
# 48  Hard Skill        76            3.37           2149                 6.71
# 49  Hard Skill       189            8.39           2146                 6.70

# %%
# remove everything in () so skills can be found in description

# split at ( and save in new column
skills['skill'] = skills['skill'].str.split('(').str[0]
skills.head()
# Out:
#             skill    skill_clean        type  count_20  frequency_%_20  \
# 0            SQL             sql  Hard Skill      1389           61.65
# 1  Communications  communication  Soft Skill      1154           51.22
# 2   Visualization  visualization  Hard Skill       517           22.95
# 3        Tableau         tableau  Hard Skill       620           27.52
# 4       Dashboard      dashboard  Hard Skill       533           23.66
#
#    count_current  frequency_%_current
# 0          18351                57.31
# 1          16024                50.04
# 2          11400                35.60
# 3          10113                31.58
# 4           9736                30.40

# %%
# load to database

from dotenv import load_dotenv
load_dotenv()

# write dataset into database

# Import get_engine from sql_functions.py. You will need to restart your kernel and rerun at this point since we changed the module since we first imported it.
from sql_functions import get_engine
# create a variable called engine using the get_engine function
engine = get_engine()

import psycopg2

table_name = 'skills_list_final'
schema = 'capstone_datacvpro'

# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        skills.to_sql(name=table_name, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema=schema, # your class schema variable
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The skills_list_final table was imported successfully.
